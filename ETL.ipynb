# %%
import pandas as pd 
#import pandas_alive
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
from summarytools import dfSummary

# %% [markdown]
# ETL Extracción, transformación y carga de los datos.
#
# lectura de los datasets.

# %%
homicidios_hecho = pd.read_excel("Datasets/homicidios.xlsx", sheet_name="HECHOS")
homicidios_victima = pd.read_excel("Datasets/homicidios.xlsx", sheet_name="VICTIMAS")
comuna = pd.read_excel("Datasets/comunas.xlsx")

# %% [markdown]
# Vamos a trabajar con lo datos de homicidios, especificamente  en la tabla de hechos.

# %%
print(homicidios_hecho.info())
homicidios_hecho.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  pos x                  696 non-null    object
#  17  pos y                  696 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                696 non-null    object
#  20  ACUSADO                696 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(14)
# memory usage: 114.3+ KB
# None
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO         SD
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS
#
# [5 rows x 21 columns]

# %% [markdown]
# Vamos a proceder a estudiar  lo valores nulos  de este dataset.

# %%
valores =homicidios_hecho.isnull().sum()
print(valores)
# Out:
# ID                         0
# N_VICTIMAS                 0
# FECHA                      0
# AAAA                       0
# MM                         0
# DD                         0
# HORA                       0
# HH                         0
# LUGAR_DEL_HECHO            0
# TIPO_DE_CALLE              0
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# COMUNA                     0
# XY (CABA)                  0
# pos x                      0
# pos y                      0
# PARTICIPANTES              0
# VICTIMA                    0
# ACUSADO                    0
# dtype: int64

# %% [markdown]
# Podemos observar  que lo valores nulos están concentrados en las columnas  calle, Altura y Cruce. Vamos a proceder hacer un estudio de manera detallada.

# %%
selected_Estudio = homicidios_hecho[['Altura', 'Calle', 'Dirección Normalizada', 'Cruce']]

# %%
selected_Estudio.head()
# Out:
#    Altura             Calle  \
# 0     NaN  PIEDRA BUENA AV.
# 1     NaN    PAZ, GRAL. AV.
# 2  2034.0    ENTRE RIOS AV.
# 3     NaN    LARRAZABAL AV.
# 4     NaN      SAN JUAN AV.
#
#                                Dirección Normalizada  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.
# 2                                ENTRE RIOS AV. 2034
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.
#
#                                  Cruce
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.

# %%
selected_Estudio.isnull()
# Out:
#      Altura  Calle  Dirección Normalizada  Cruce
# 0      True  False                  False  False
# 1      True  False                  False  False
# 2     False  False                  False   True
# 3      True  False                  False  False
# 4      True  False                  False  False
# ..      ...    ...                    ...    ...
# 691    True  False                  False  False
# 692    True  False                  False  False
# 693    True  False                  False  False
# 694   False  False                  False   True
# 695   False  False                  False   True
#
# [696 rows x 4 columns]

# %% [markdown]
# Al estudiar el  dataset, podemos tomar las siguientes desiciones en cuanto a los valores nulos:
# - Para el caso de la columna **calle** tenemos un solo dato nulo.
# - La columna **dirección Normalizada** contiene 8 nulos.
# - La columna **Cruce** no enontramos con 171 valores nulos, esto equivale a 24.56% de los datos de la columna.
# - Para la columna altura tiene un total de 567 nulos, esto representa el 81,5% de datos de la columna.
#
# Con respecto a la culumna **Calle**  , la dejaremos sin nungun tipo de modificación, la columna **dirección normalizada** no tiene alternativa de poder completarse con las columnas del dataset, solo contiene el 1.1% de nulos por lo que la conservaremos.
# La columna **cruce** solo va ha  tener datos cuando el hecho se produce en un cruce de calles, por tal motivo la  vamos  a conservar.
#
# Al observar  la columna altura prodedemos a eliminarla, debido a la gran cantidad de valores faltantes, en este sentido no hay posibilidad de rellenar columna.

# %%
homicidios_hecho= homicidios_hecho.drop("Altura", axis=1)
homicidios_hecho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Cruce                  525 non-null    object
#  12  Dirección Normalizada  688 non-null    object
#  13  COMUNA                 696 non-null    int64
#  14  XY (CABA)              696 non-null    object
#  15  pos x                  696 non-null    object
#  16  pos y                  696 non-null    object
#  17  PARTICIPANTES          696 non-null    object
#  18  VICTIMA                696 non-null    object
#  19  ACUSADO                696 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(14)
# memory usage: 108.9+ KB

# %% [markdown]
# Vamos a estudiar los valores duplicados.

# %%
duplicados= homicidios_hecho.duplicated().sum()
print(duplicados)
# Out:
# 0

# %% [markdown]
# Observamos que no tenemos duplicados.

# %% [markdown]
# vamos a transformar los valores de la columna HH a tipo numérico, ya que estan tipo object.

# %%
# Cambio el dato horas  a tipo de dato numerico y luego a entero 
homicidios_hecho["HH"] = pd.to_numeric(homicidios_hecho ["HH"], errors="coerce")
homicidios_hecho["HH"] = homicidios_hecho["HH"].astype("Int64")

# %% [markdown]
# Las coordenadas X y Y debemos  transformar el tipo de dato ya que  estan en tipo Objeto.  estan deben para a tipo float(), tambien debemos revisar que  posicionen no son válidas.

# %%
# Filtrar filas con posiciones no válidas
valid_positions = ~(homicidios_hecho['pos x'].str.contains('[^0-9.,-]') | homicidios_hecho['pos y'].str.contains('[^0-9.,-]') )

# %%
# Establecer posiciones no válidas en NaN
homicidios_hecho.loc[~valid_positions, ['pos x', 'pos y']] = np.nan

# %%
homicidios_hecho['pos y'] = pd.to_numeric(homicidios_hecho['pos y'].str.replace(',', '.'), errors='coerce')

# %% [markdown]
# Aca transformamos los valores de latitud y  longitud a tipo float.

# %%
homicidios_hecho['pos x'] = pd.to_numeric(homicidios_hecho['pos x'].astype(str).str.replace(',', '.'), errors='coerce').astype(float)
homicidios_hecho['pos y'] = pd.to_numeric(homicidios_hecho['pos y'].astype(str).str.replace(',', '.'), errors='coerce').astype(float)

# %%
homicidios_hecho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     695 non-null    Int64
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Cruce                  525 non-null    object
#  12  Dirección Normalizada  688 non-null    object
#  13  COMUNA                 696 non-null    int64
#  14  XY (CABA)              696 non-null    object
#  15  pos x                  684 non-null    float64
#  16  pos y                  684 non-null    float64
#  17  PARTICIPANTES          696 non-null    object
#  18  VICTIMA                696 non-null    object
#  19  ACUSADO                696 non-null    object
# dtypes: Int64(1), datetime64[ns](1), float64(2), int64(5), object(11)
# memory usage: 109.6+ KB

# %% [markdown]
# Vamos ha revisar el dataset que hemos traido de la pagina https://data.buenosaires.gob.ar/dataset/comunas donde se especifica el nombre de cada una de las comunas. esto con la finalidad de darle valor agregado al dataset, con esta información el dataset tendra información  de la descripción de cada una de las comunas con los barrios que la conforman.

# %%
comuna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         15 non-null     int64
#  1   OBJETO     15 non-null     object
#  2   COMUNAS    15 non-null     int64
#  3   BARRIOS    15 non-null     object
#  4   PERIMETRO  15 non-null     float64
#  5   AREA       15 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 852.0+ bytes

# %%
comuna.head()
# Out:
#    ID          OBJETO  COMUNAS                                  BARRIOS  \
# 0   1  LIMITE COMUNAL        2                                 RECOLETA
# 1   2  LIMITE COMUNAL        5                          ALMAGRO - BOEDO
# 2   3  LIMITE COMUNAL        6                                CABALLITO
# 3   4  LIMITE COMUNAL        7                FLORES - PARQUE CHACABUCO
# 4   5  LIMITE COMUNAL        9  LINIERS - MATADEROS - PARQUE AVELLANEDA
#
#       PERIMETRO          AREA
# 0  21452.838648  6.317265e+06
# 1  12323.432479  6.660603e+06
# 2  10990.964471  6.851029e+06
# 3  17972.257870  1.242290e+07
# 4  21411.738344  1.650531e+07

# %%
print(homicidios_hecho.columns)
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA', 'AAAA', 'MM', 'DD', 'HORA', 'HH',
#        'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Altura', 'Cruce',
#        'Dirección Normalizada', 'COMUNA', 'XY (CABA)', 'pos x', 'pos y',
#        'PARTICIPANTES', 'VICTIMA', 'ACUSADO'],
#       dtype='object')

# %% [markdown]
# Debemos renombrar el nombre de la columna COMUNA a COMUNAS  para poder realizar el merge.

# %%
homicidios_hecho=homicidios_hecho.rename(columns={
    "COMUNA": "COMUNAS"
})

# %%
print(homicidios_hecho.columns)
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA', 'AAAA', 'MM', 'DD', 'HORA', 'HH',
#        'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Altura', 'Cruce',
#        'Dirección Normalizada', 'COMUNAS', 'XY (CABA)', 'pos x', 'pos y',
#        'PARTICIPANTES', 'VICTIMA', 'ACUSADO'],
#       dtype='object')

# %%
homicidios_hecho = homicidios_hecho.merge(comuna, on="COMUNAS", how="left")

# %% [markdown]
# Vamos a crear una nueva columna con el nombre del  dia de la semana que corresponde el siniestro, con esto podremos  ver como  es el comportamiento de  los siniestros por cada dia, podriamos estudiar los fines de semana en conjunto tambien y comparar con los dias de semana.

# %%
#Creo una columna nueva `Día semana` que contenga el nombre del día de la semana
homicidios_hecho['DIA SEMANA'] = homicidios_hecho['FECHA'].dt.strftime('%A')

#Creo un diccionario para modificar a español los nombres de los dás de la semana y lo aplico a la columna nueva
dic={  'Friday':'Viernes',
       'Saturday': 'Sabado',
       'Sunday': 'Domingo',  
       'Thursday': 'Jueves',
        'Monday': 'Lunes',
        'Wednesday': 'Miercoles',
       'Tuesday': 'Martes'}
homicidios_hecho['DIA SEMANA'] =homicidios_hecho['DIA SEMANA'].replace(dic)

# %%
homicidios_hecho.head()
# Out:
#         ID_x  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...         pos y  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...  -34.68757022
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...  -34.66977709
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  -34.63189362
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...  -34.68092974
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO  ID_y          OBJETO  \
# 0       MOTO-AUTO    MOTO       AUTO  12.0  LIMITE COMUNAL
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS   5.0  LIMITE COMUNAL
# 2       MOTO-AUTO    MOTO       AUTO  14.0  LIMITE COMUNAL
# 3         MOTO-SD    MOTO         SD  12.0  LIMITE COMUNAL
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS  14.0  LIMITE COMUNAL
#
#                                              BARRIOS     PERIMETRO  \
# 0     VILLA LUGANO - VILLA RIACHUELO - VILLA SOLDATI  20935.012513
# 1            LINIERS - MATADEROS - PARQUE AVELLANEDA  21411.738344
# 2  CONSTITUCION - MONTSERRAT - PUERTO MADERO - RE...  36102.201573
# 3     VILLA LUGANO - VILLA RIACHUELO - VILLA SOLDATI  20935.012513
# 4  CONSTITUCION - MONTSERRAT - PUERTO MADERO - RE...  36102.201573
#
#            AREA DIA SEMANA
# 0  2.221690e+07    Viernes
# 1  1.650531e+07     Sabado
# 2  1.779457e+07    Domingo
# 3  2.221690e+07    Domingo
# 4  1.779457e+07     Jueves
#
# [5 rows x 27 columns]

# %%
dfSummary(homicidios_hecho)
# Out:
# <style type="text/css">
# #T_eaddb thead>tr>th {
#   text-align: left;
# }
# #T_eaddb_row0_col0, #T_eaddb_row1_col0, #T_eaddb_row2_col0, #T_eaddb_row3_col0, #T_eaddb_row4_col0, #T_eaddb_row5_col0, #T_eaddb_row6_col0, #T_eaddb_row7_col0, #T_eaddb_row8_col0, #T_eaddb_row9_col0, #T_eaddb_row10_col0, #T_eaddb_row11_col0, #T_eaddb_row12_col0, #T_eaddb_row13_col0, #T_eaddb_row14_col0, #T_eaddb_row15_col0, #T_eaddb_row16_col0, #T_eaddb_row17_col0, #T_eaddb_row18_col0, #T_eaddb_row19_col0, #T_eaddb_row20_col0, #T_eaddb_row21_col0, #T_eaddb_row22_col0, #T_eaddb_row23_col0, #T_eaddb_row24_col0, #T_eaddb_row25_col0, #T_eaddb_row26_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_eaddb_row0_col1, #T_eaddb_row1_col1, #T_eaddb_row2_col1, #T_eaddb_row3_col1, #T_eaddb_row4_col1, #T_eaddb_row5_col1, #T_eaddb_row6_col1, #T_eaddb_row7_col1, #T_eaddb_row8_col1, #T_eaddb_row9_col1, #T_eaddb_row10_col1, #T_eaddb_row11_col1, #T_eaddb_row12_col1, #T_eaddb_row13_col1, #T_eaddb_row14_col1, #T_eaddb_row15_col1, #T_eaddb_row16_col1, #T_eaddb_row17_col1, #T_eaddb_row18_col1, #T_eaddb_row19_col1, #T_eaddb_row20_col1, #T_eaddb_row21_col1, #T_eaddb_row22_col1, #T_eaddb_row23_col1, #T_eaddb_row24_col1, #T_eaddb_row25_col1, #T_eaddb_row26_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_eaddb_row0_col2, #T_eaddb_row1_col2, #T_eaddb_row2_col2, #T_eaddb_row3_col2, #T_eaddb_row4_col2, #T_eaddb_row5_col2, #T_eaddb_row6_col2, #T_eaddb_row7_col2, #T_eaddb_row8_col2, #T_eaddb_row9_col2, #T_eaddb_row10_col2, #T_eaddb_row11_col2, #T_eaddb_row12_col2, #T_eaddb_row13_col2, #T_eaddb_row14_col2, #T_eaddb_row15_col2, #T_eaddb_row16_col2, #T_eaddb_row17_col2, #T_eaddb_row18_col2, #T_eaddb_row19_col2, #T_eaddb_row20_col2, #T_eaddb_row21_col2, #T_eaddb_row22_col2, #T_eaddb_row23_col2, #T_eaddb_row24_col2, #T_eaddb_row25_col2, #T_eaddb_row26_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_eaddb_row0_col3, #T_eaddb_row1_col3, #T_eaddb_row2_col3, #T_eaddb_row3_col3, #T_eaddb_row4_col3, #T_eaddb_row5_col3, #T_eaddb_row6_col3, #T_eaddb_row7_col3, #T_eaddb_row8_col3, #T_eaddb_row9_col3, #T_eaddb_row10_col3, #T_eaddb_row11_col3, #T_eaddb_row12_col3, #T_eaddb_row13_col3, #T_eaddb_row14_col3, #T_eaddb_row15_col3, #T_eaddb_row16_col3, #T_eaddb_row17_col3, #T_eaddb_row18_col3, #T_eaddb_row19_col3, #T_eaddb_row20_col3, #T_eaddb_row21_col3, #T_eaddb_row22_col3, #T_eaddb_row23_col3, #T_eaddb_row24_col3, #T_eaddb_row25_col3, #T_eaddb_row26_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_eaddb_row0_col4, #T_eaddb_row1_col4, #T_eaddb_row2_col4, #T_eaddb_row3_col4, #T_eaddb_row4_col4, #T_eaddb_row5_col4, #T_eaddb_row6_col4, #T_eaddb_row7_col4, #T_eaddb_row8_col4, #T_eaddb_row9_col4, #T_eaddb_row10_col4, #T_eaddb_row11_col4, #T_eaddb_row12_col4, #T_eaddb_row13_col4, #T_eaddb_row14_col4, #T_eaddb_row15_col4, #T_eaddb_row16_col4, #T_eaddb_row17_col4, #T_eaddb_row18_col4, #T_eaddb_row19_col4, #T_eaddb_row20_col4, #T_eaddb_row21_col4, #T_eaddb_row22_col4, #T_eaddb_row23_col4, #T_eaddb_row24_col4, #T_eaddb_row25_col4, #T_eaddb_row26_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_eaddb_row0_col5, #T_eaddb_row1_col5, #T_eaddb_row2_col5, #T_eaddb_row3_col5, #T_eaddb_row4_col5, #T_eaddb_row5_col5, #T_eaddb_row6_col5, #T_eaddb_row7_col5, #T_eaddb_row8_col5, #T_eaddb_row9_col5, #T_eaddb_row10_col5, #T_eaddb_row11_col5, #T_eaddb_row12_col5, #T_eaddb_row13_col5, #T_eaddb_row14_col5, #T_eaddb_row15_col5, #T_eaddb_row16_col5, #T_eaddb_row17_col5, #T_eaddb_row18_col5, #T_eaddb_row19_col5, #T_eaddb_row20_col5, #T_eaddb_row21_col5, #T_eaddb_row22_col5, #T_eaddb_row23_col5, #T_eaddb_row24_col5, #T_eaddb_row25_col5, #T_eaddb_row26_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_eaddb">
#   <caption><strong>Data Frame Summary</strong><br>homicidios_hecho<br>Dimensions: 696 x 27<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_eaddb_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_eaddb_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_eaddb_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_eaddb_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_eaddb_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_eaddb_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eaddb_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_eaddb_row0_col1" class="data row0 col1" ><strong>ID_x</strong><br>[object]</td>
#       <td id="T_eaddb_row0_col2" class="data row0 col2" >1. 2016-0001<br>2. 2019-0050<br>3. 2019-0042<br>4. 2019-0043<br>5. 2019-0044<br>6. 2019-0045<br>7. 2019-0046<br>8. 2019-0047<br>9. 2019-0048<br>10. 2019-0049<br>11. other</td>
#       <td id="T_eaddb_row0_col3" class="data row0 col3" >1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>686 (98.6%)</td>
#       <td id="T_eaddb_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_eaddb_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_eaddb_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_eaddb_row1_col1" class="data row1 col1" ><strong>N_VICTIMAS</strong><br>[int64]</td>
#       <td id="T_eaddb_row1_col2" class="data row1 col2" >Mean (sd) : 1.0 (0.2)<br>min < med < max:<br>1.0 < 1.0 < 3.0<br>IQR (CV) : 0.0 (5.7)</td>
#       <td id="T_eaddb_row1_col3" class="data row1 col3" >3 distinct values</td>
#       <td id="T_eaddb_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_eaddb_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_eaddb_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_eaddb_row2_col1" class="data row2 col1" ><strong>FECHA</strong><br>[datetime64[ns]]</td>
#       <td id="T_eaddb_row2_col2" class="data row2 col2" >Min: 2016-01-01<br>Max: 2021-12-30<br>Duration: 2,190 days</td>
#       <td id="T_eaddb_row2_col3" class="data row2 col3" >598 distinct values</td>
#       <td id="T_eaddb_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_eaddb_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_eaddb_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_eaddb_row3_col1" class="data row3 col1" ><strong>AAAA</strong><br>[int64]</td>
#       <td id="T_eaddb_row3_col2" class="data row3 col2" >Mean (sd) : 2018.2 (1.7)<br>min < med < max:<br>2016.0 < 2018.0 < 2021.0<br>IQR (CV) : 3.0 (1198.6)</td>
#       <td id="T_eaddb_row3_col3" class="data row3 col3" >6 distinct values</td>
#       <td id="T_eaddb_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_eaddb_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_eaddb_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_eaddb_row4_col1" class="data row4 col1" ><strong>MM</strong><br>[int64]</td>
#       <td id="T_eaddb_row4_col2" class="data row4 col2" >Mean (sd) : 6.7 (3.6)<br>min < med < max:<br>1.0 < 7.0 < 12.0<br>IQR (CV) : 6.0 (1.9)</td>
#       <td id="T_eaddb_row4_col3" class="data row4 col3" >12 distinct values</td>
#       <td id="T_eaddb_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_eaddb_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_eaddb_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_eaddb_row5_col1" class="data row5 col1" ><strong>DD</strong><br>[int64]</td>
#       <td id="T_eaddb_
